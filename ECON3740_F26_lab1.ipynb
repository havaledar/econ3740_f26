# %% [markdown]
# <a href="https://colab.research.google.com/github/havaledar/econ3740_f26/blob/main/ECON3740_F26_lab1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Python Notebook
#
# Python is the programming language, Jupyter Notebook is the interface where we run Python code. So, we need to have both. We can either install on your local machine or use Google Colab.

# %% [markdown]
# ## Local Machine

# %% [markdown]
# * Method 1: Anaconda
# You can download the Anaconda and use Jupyter Notebook to code in Python.
# https://www.anaconda.com/download
#
# * Method 2: Python and IDE
# You can download Python from here.
# https://www.python.org/downloads/
#
# Then you need to use an IDE(e.g. VS Code) to use Jupyter Notebook.
# https://code.visualstudio.com/download

# %% [markdown]
# ## Google Colab

# %% [markdown]
# You can craete a Notebook with Google Colab without installing anything by using Google Colab.
# https://colab.new/

# %% [markdown]
# # Jupyter Notebook interface
#
# The Jupyter Notebook has a web-based interface with different panels.

# %% [markdown]
# ## Cells
# A notebook is a list of cells. Cells contain either explanatory text or executable code and its output. Click a cell to select it.

# %% [markdown]
# ### Code cells
# Below is a **code cell**. Once the toolbar button indicates CONNECTED, click in the cell to select it and execute the contents in the following ways:
#
# * Click the **Play icon** in the left gutter of the cell;
# * Type **Cmd/Ctrl+Enter** to run the cell in place;
# * Type **Shift+Enter** to run the cell and move focus to the next cell (adding one if none exists); or
# * Type **Alt+Enter** to run the cell and insert a new code cell immediately below it.
#
# There are additional options for running some or all cells in the **Runtime** menu.

# %% [markdown]
# ![Screenshot from 2023-11-07 21-35-10.png](data:image/png;base64,...)

# %%
a = 10
a
# Out:
# 10

# %% [markdown]
# You can type Python code into the code cells and run them to execute. The menu and toolbar have options for running code, adding cells, and more.

# %% [markdown]
# ### Text cells
# This is a **text cell**. You can **double-click** to edit this cell. Text cells
# use markdown syntax. To learn more, see our [markdown
# guide](/notebooks/markdown_guide.ipynb).
#
# You can also add math to text cells using [LaTeX](http://www.latex-project.org/)
# to be rendered by [MathJax](https://www.mathjax.org). Just place the statement
# within a pair of **\$** signs. For example `$\sqrt{3x-1}+(1+x)^2$` becomes
# $\sqrt{3x-1}+(1+x)^2.$

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Output of code cells

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Sidebar

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# # Integration with Drive
#
# Colaboratory is integrated with Google Drive. It allows you to share, comment, and collaborate on the same document with multiple people:
#
# * The **SHARE** button (top-right of the toolbar) allows you to share the notebook and control permissions set on it.
#
# **If you have any questions about your codes, please share your notebook with me.**
#
# * **File->Make a Copy** creates a copy of the notebook in Drive.
#
# * **File->Save** saves the File to Drive. **File->Save and checkpoint** pins the version so it doesn't get deleted from the revision history.
#
# * **File->Revision history** shows the notebook's revision history.

# %% [markdown]
# # Commenting on a cell
# You can comment on a Colaboratory notebook like you would on a Google Document. Comments are attached to cells, and are displayed next to the cell they refer to. If you have **comment-only** permissions, you will see a comment button on the top right of the cell when you hover over it.
#
# If you have edit or comment permissions you can comment on a cell in one of three ways:
#
# 1. Select a cell and click the comment button in the toolbar above the top-right corner of the cell.
# 1. Right click a text cell and select **Add a comment** from the context menu.
# 3. Use the shortcut **Ctrl+Shift+M** to add a comment to the currently selected cell.
#
# You can resolve and reply to comments, and you can target comments to specific collaborators by typing *+[email address]* (e.g., `+user@domain.com`). Addressed collaborators will be emailed.
#
# The Comment button in the top-right corner of the page shows all comments attached to the notebook.

# %% [markdown]
# # Assignments

# %% [markdown]
# ## Organized
#
# Keep it a tidy and easiy to read document by using:
# * Proper formatting, and
# * Logically arranged table of contents.

# %% [markdown]
# ## Reproducible
#
# Submit your assigments so your documents are reproducible.
#
# *   Do not use local files.
# *   Make sure your codes run before submission.

# %% [markdown]
# # GitHub
#
# Public notebooks saved on GitHub can be directly opened in Google Colab, with no required authorization step. Also, Google Colab Notebooks can be saved to GitHub.

# %% [markdown]
# # Submission
#
# You have to download the Notebook file, rename the *.ipynb file to a *.txt file and submit it to the Dropbox. URL submission will not be accepted.

# %% [markdown]
# # More resrouces
#
# - [Overview of Colaboratory](/notebooks/basic_features_overview.ipynb)
# - [Guide to Markdown](/notebooks/markdown_guide.ipynb)

# %% [markdown]
# # Libraries

# %% [markdown]
# There are many libraries in Python developed for different applications. Before using them, you should import them first. It is a common practice to use abbrevation of library names by "as" so that you can refer to this library easier.
#
# ```
# import pandas as pd
# ```
#
# If the library has not been installed, you should install it first before importing it. Pandas is already installed in Google Colab. So there is no need to install it again.
#
# ```
# # !pip install wooldridge
#
# import wooldridge as st
# ```

# %%
import pandas as pd

# %%
# !pip install wooldridge
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.1/5.1 MB 32.7 MB/s eta 0:00:00
# ...

# %%
import wooldridge as woo

# %%
import numpy as np

# %% [markdown]
# # Reading Data

# %% [markdown]
# This section introduces some easy ways to read data into Python Pandas. While there are many options, I find these to be the simplest.
#
# The data files that Pandas can directly import should be in .csv format, Excel .xlsx, or Stata .dta format. There is no need to save data in a Python-specific format.

# %% [markdown]
# ## read_stata

# %% [markdown]
# Once the file is uploaded and the libraries you are going to use imported, you can read it into a DataFrame.
#
# ```python
# data = pd.read_stata('file.dta')
# ```
#
# Make sure the filename matches the uploaded file.
#
# You can also reference the full Google Colab filesystem path if needed:
#
# ```
# data = pd.read_stata('/content/file.dta')
# ```
#
# For example, we can import a dta file of survey data downloaded from a website:
#
# To read a dta file into a DataFrame:
#
# ```python
# data = pd.read_stata('LFS-71M0001-E-2023-August_F1.dta')
# ```
#
# Pandas will automatically convert the data into a DataFrame.
#
# Here is the documentation for read_stata.
# https://colab.research.google.com/corgiredirector?site=https%3A%2F%2Fpandas.pydata.org%2Fdocs%2Freference%2Fapi%2Fpandas.read_stata.html

# %% [markdown]
# ## CSV and Excel files

# %% [markdown]
# Then to read Excel:
#
# ```python
# data = pd.read_excel('data.xlsx')
# ```
#
# Or CSV:
#
# ```python
# data = pd.read_csv('data.csv')
# ```

# %%
data = pd.read_excel('/content/meap01.xlsx')

# %%
data
# Out:
#       Unnamed: 0    dcode  bcode      math4      read4      lunch  enroll  \
# 0              0   1010.0   4937  83.300003  77.800003  40.599998     468
# 1              1   2070.0    597  90.300003  82.300003  27.100000     679
# 2              2   2080.0   4860  61.900002  71.400002  41.750000     400
# 3              3   3010.0    790  85.699997  60.000000  12.750000     251
# 4              4   3010.0   1403  77.300003  59.099998  17.080000     439
# ...          ...      ...    ...        ...        ...        ...     ...
# 1818        1818  83010.0   2024  93.599998  57.400002  50.529999     285
# 1819        1819  83010.0   2210  69.000000  48.799999  53.670002     259
# 1820        1820  83010.0   2480  72.500000  63.400002  46.849998     254
# 1821        1821  83010.0   5101  81.000000  73.800003  34.299999     277
# 1822        1822  83070.0   2527  88.099998  56.700001  52.920002     650
#
#          expend        exppp   lenroll    lexpend    lexppp
# ...

# %% [markdown]
# ### describe
# Display summary statistics
# ```
# mydata.describe()
# ```

# %%
data.describe()
# Out:
#         Unnamed: 0         dcode        bcode        math4        read4  \
# count  1823.000000   1823.000000  1823.000000  1823.000000  1823.000000
# mean    911.000000  53028.266045  3394.556775    71.908996    60.061876
# std     526.399088  23907.061075  2442.928934    19.954092    19.147292
# min       0.000000   1010.000000     1.000000     0.000000     0.000000
# 25%     455.500000  33901.500000  1385.500000    61.600000    48.900002
# 50%     911.000000  55100.000000  2794.000000    76.400002    62.700001
# 75%    1366.500000  77010.000000  5084.500000    87.000000    73.900002
# max    1822.000000  83070.000000  8838.000000   100.000000   100.000000
#
#              lunch       enroll        expend         exppp      lenroll  \
# count  1823.000000  1823.000000  1.823000e+03   1823.000000  1823.000000
# mean     39.251903   401.935820  2.036984e+06   5194.865478     5.910937
# std      26.416717   169.825728  8.649361e+05   1091.889597     0.420448
# ...

# %% [markdown]
# # Min/Max

# %%
data['math4'].max()
#data['read4'].min()
# Out:
# 100.0

# %% [markdown]
# # Columns
#
# Keep only certain variables

# %% [markdown]
# # Select a column

# %%
data['math4']

# %% [markdown]
# # Sort

# %%
data.sort_values(by='math4', ascending=False)
# Out:
#       Unnamed: 0    dcode  bcode  math4       read4      lunch  enroll  \
# 1082        1082  63130.0   4159  100.0   89.500000  36.180000     199
# 1096        1096  63150.0   6365  100.0   79.699997   5.850000     427
# 1094        1094  63150.0   6124  100.0   96.400002   2.450000     489
# 33            33   5010.0   6938  100.0  100.000000  53.890003     180
# 1088        1088  63150.0   2161  100.0   93.500000   1.990000     403
# ...          ...      ...    ...    ...         ...        ...     ...
# 1189        1189  63906.0   8433    7.1   17.900000  84.559998     259
# 1556        1556  82010.0   2991    6.3    0.000000  82.690002     387
# 1666        1666  82070.0   2178    5.4    5.400000  89.470001     589
# 1809        1809  82955.0   8724    3.6    5.500000  68.930000     457
# 973          973  59901.0   8478    0.0    8.000000  82.510002     183
#
#          expend        exppp   lenroll    lexpend    lexppp
# ...

# %% [markdown]
# # shape
# Get dimensions (rows, columns)
# ```python
# data.shape
# ```

# %%
data.shape
# Out:
# (103403, 60)

# %% [markdown]
# # value count

# %%
data['math4'].value_counts()
# Out:
# math4
# 100.000000    38
# 75.000000     22
# 50.000000     17
# 83.300003     15
# 80.000000     12
#               ..
# 61.799999      1
# 29.600000      1
# 77.699997      1
# 48.200001      1
# 8.600000       1
# Name: count, Length: 585, dtype: int64

# %% [markdown]
# # Filter

# %%
data[data['math4']==100].shape
# Out:
# (38, 12)

# %%
data[data['math4']==100].shape[0]/data.shape[0]*100
# Out:
# 2.084476138233681

# %%
data[data['math4'] == 50].shape[0]
# Out:
# 17

# %% [markdown]
# # Mean and SD

# %%
data['math4'].mean()
# Out:
# 71.90899606805154

# %%
data['read4'].mean()
# Out:
# 60.06187602862904

# %%
data['exppp'].mean()
# Out:
# 5194.865478314741

# %%
data['exppp'].std()
# Out:
# 1091.8895972167836

# %%
data['exppp'].std()/data['exppp'].mean()
# Out:
# 0.2101863083413282

# %% [markdown]
# # Correlation

# %%
data['read4'].corr(data['math4'])
# Out:
# 0.842728145772116

# %% [markdown]
# # math operations

# %%
(8000-4000)/4000*100
# Out:
# 100.0

# %%
data['LFSSTAT'].value_counts().sort_values()
# Out:
# 3     4139
# 2     9253
# 4    37500
# 1    52511
# Name: LFSSTAT, dtype: int64

# %%
import numpy as np

100*(np.log(8000)-np.log(4000))
# Out:
# 69.31471805599455
